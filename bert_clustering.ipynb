# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import pandas as pd
from matplotlib import pyplot as plt

# %%
embedder = SentenceTransformer('all-MiniLM-L6-v2')

# %%
df = pd.read_excel("data/Processed Song Dataset.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         1969 non-null   object
#  1   Lyrics         1969 non-null   object
#  2   Song Title     1969 non-null   object
#  3   Year           1969 non-null   int64
#  4   Popularity     1969 non-null   int64
#  5   en_prob        1969 non-null   float64
#  6   cleanedLyrics  1969 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 107.8+ KB

# %%
corpus_embeddings = embedder.encode(df["Lyrics"].to_list())

# %%
# Perform kmean clustering
candidates = list(range(2, 100))
scores = [0] * len(candidates)
for i, candidate in enumerate(candidates):
    clustering_model = KMeans(n_clusters=candidate)
    clustering_model.fit(corpus_embeddings)
    scores[i] = clustering_model.inertia_

# %%
plt.plot(candidates, scores);

# %%
best = 10

# %%
clustering_model = KMeans(n_clusters=best)
clustering_model.fit(corpus_embeddings)
df["Cluster"] = clustering_model.labels_

# %%
df
# Out:
#                                              Artist  \
# 0                      Santana Featuring Rob Thomas
# 1                                    Brian McKnight
# 2                                   Jessica Simpson
# 3                                   Whitney Houston
# 4                                     Savage Garden
# ...                                             ...
# 1964                                   Ant Saunders
# 1965   Roddy Ricch Featuring A Boogie Wit da Hoodie
# 1966                                       Doja Cat
# 1967                                     Russ & BIA
# 1968  Ed Sheeran Featuring Camila Cabello & Cardi B
#
#                                                  Lyrics  \
# 0     Man, it's a hot one Like seven inches from the...
# 1     It's undeniable That we should be together It'...
# 2     Ooh, ooh, mmm  You set my soul at ease Chased ...
# 3     Clap your hands, y'all It's alright Turn me up...
# ...

# %%
df.groupby("Artist").count().sort_values(by="Lyrics", ascending=False).head()
# Out:
#               Lyrics  Song Title  Year  Popularity  en_prob  cleanedLyrics  \
# Artist
# Taylor Swift      19          19    19          19       19             19
# Tim McGraw        14          14    14          14       14             14
# Mariah Carey      14          14    14          14       14             14
# J. Cole           12          12    12          12       12             12
# Beyonce           12          12    12          12       12             12
#
#               Cluster
# Artist
# Taylor Swift       19
# Tim McGraw         14
# Mariah Carey       14
# J. Cole            12
# Beyonce            12

# %%
df.loc[df["Artist"] == "Mariah Carey"].groupby("Cluster").count()["Song Title"].reset_index()
# Out:
#    Cluster  Song Title
# 0        3           9
# 1        4           2
# 2        5           2
# 3        8           1

# %%
df.loc[(df["Artist"] == "Mariah Carey") & (df["Cluster"] == 3)]
# Out:
#             Artist                                             Lyrics  \
# 1130  Mariah Carey  Oh, Santa's gon' come and make him mine this C...
# 1246  Mariah Carey  I don't want a lot for Christmas There is just...
# 1348  Mariah Carey  I don't want a lot for Christmas There is just...
# 1450  Mariah Carey  I don't want a lot for Christmas There is just...
# 1528  Mariah Carey  I don't want a lot for Christmas There is just...
# 1620  Mariah Carey  I don't want a lot for Christmas There is just...
# 1707  Mariah Carey  I don't want a lot for Christmas There is just...
# 1791  Mariah Carey  I don't want a lot for Christmas There is just...
# 1878  Mariah Carey  I don't want a lot for Christmas There is just...
#
#                            Song Title  Year  Popularity   en_prob  \
# 1130                        Oh Santa!  2011          71  0.999998
# 1246  All I Want For Christmas Is You  2013          87  0.999997
# 1348  All I Want For Christmas Is You  2014          87  0.999997
# ...

# %%
df.loc[(df["Artist"] == "Mariah Carey") & (df["Cluster"] == 4)]
# Out:
#            Artist                                             Lyrics  \
# 276  Mariah Carey  You're with me Til the bitter end What we have...
# 361  Mariah Carey  When you get caught in the rain With nowhere t...
#
#                     Song Title  Year  Popularity   en_prob  \
# 276  Never Too Far/Hero Medley  2002           0  0.999997
# 361           Through The Rain  2003          46  0.999998
#
#                                          cleanedLyrics  Cluster
# 276  your with til the bitter end what have transce...        4
# 361  when you get caught the rain with nowher run w...        4

# %%
df.loc[(df["Artist"] == "Mariah Carey") & (df["Cluster"] == 5)]
# Out:
#            Artist                                             Lyrics  \
# 566  Mariah Carey  Don't forget about us Don't baby, don't baby, ...
# 609  Mariah Carey  Sweet love, yeah  I didn't mean it when I said...
#
#                 Song Title  Year  Popularity   en_prob  \
# 566  Don't Forget About Us  2006           0  0.999996
# 609     We Belong Together  2006          71  0.999997
#
#                                          cleanedLyrics  Cluster
# 566  dont forget about dont babi not babi not let b...        5
# 609  sweet love yeah did not mean when said did not...        5

# %%
df.loc[(df["Artist"] == "Mariah Carey") & (df["Cluster"] == 8)]
# Out:
#            Artist                                             Lyrics  \
# 607  Mariah Carey  Ooh, ooh, ooh, ooh Ooh, ooh, oh Everybody just...
#
#        Song Title  Year  Popularity   en_prob  \
# 607  Shake It Off  2006          63  0.999997
#
#                                          cleanedLyrics  Cluster
# 607  ooh ooh ooh ooh ooh ooh everybodi just everybo...        8
